# %% [markdown]
# ### Dataset Preparartion, DRR Generation (Colab, CUDA required)
#
# Run this notebook on Google Colab (T4 GPU or better). This does NOT run on the laptop locally.
#
# Generates 2 non-simultaneous cone-beam projections per case, with the DeepCA (Wang et al., WACV 2025) motion-simulation protocol (+/-10 deg rotation, +/-8mm translation on the second view), and saves projection matrices alongside every image.

# %%
# !pip install -q -r requirements-colab.txt

# %%
# TODO: mount Drive / download ImageCAS raw volumes here (see DATASET.md)
from src.coronarycl.drr import generate_case_projections, sample_motion_perturbation
# TODO: loop over data/raw cases, call generate_case_projections, save to data/processed/projections/
